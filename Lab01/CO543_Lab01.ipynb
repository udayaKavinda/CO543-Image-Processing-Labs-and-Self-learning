# %%
import cv2
# import openCV(images treats as numpy arrays,
# therefore image processing functions can be achived using numpy operations)
import numpy as np
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('/content/sample_data/a.jpg')

# %%
img=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
# print(img.dtype)
# img=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
resized_image = cv2.resize(img, (100,100))
#Reduce image to 100 cols and 50 rows
# resized_image = cv2.resize(img, (0, 0), fx=0.5, fy=0.5)
#Reduce both axes by half
# resized_image = cv2.resize(img, (0, 0), fx=0.5, fy=0.5, interpolation=cv2.INTER_NEAREST)

# Get dimensions of the image and calculate the center of the image
(h, w) = img.shape[:2]
center = (w / 2, h / 2)
# Computing the matrix (M) that can be used for rotating the image
# center - Point around which, the image is rotated
# 180 - Angle by which image is rotated
# 1.0 - Scaling factor (No scaling in this case)
M = cv2.getRotationMatrix2D(center, 180, 1.0)
# Perform the actual rotation
rotated = cv2.warpAffine(img, M, (w, h))
print(resized_image)
# Out:
# [[ 28  28  28 ...  28  28  30]
#  [ 30  30  29 ...  30  25  30]
#  [ 30 105  26 ...  27  29  30]
#  ...
#  [ 30  30  31 ...  16  30  30]
#  [ 30  30  25 ...  12  30  30]
#  [ 30  30  34 ...  26  30  30]]

# %%
cv2_imshow(resized_image )
cv2_imshow(img )

# cv2.waitKey(0)
# Wait indefinitely for a key press. Once a key is pressed,
# the program will continue to the next line of code
# cv2.destroyAllWindows() #Destroys all the OpenCV windows.
# Out:
# <PIL.Image.Image image mode=L size=100x100>
# <PIL.Image.Image image mode=L size=2400x1599>
